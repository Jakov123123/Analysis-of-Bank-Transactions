# %% [markdown]
# # **Analysis of Bank Transactions**
# # Author: Jakov Vodanović

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Importing libraries *pandas* and *numpy*.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let's take a look at the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Uvod u podatkovnu znanost/Projekt # To run this yourself, you'll have to change this to so it's
                                                             # consistent with your location of the bank_transactions.csv
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Uvod u podatkovnu znanost/Projekt

# %%
data = pd.read_csv('bank_transactions.csv')
data.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %% [markdown]
# First, let's check if the CustomerID is functional. Then, we need to combine TransactionTime and TransactionDate into a DateTime type and convert CustomerDOB to a DateTime type.

# %%
data[data['CustomerID'] == "C5841053"] #samo jedna transakcija za prvu osobu, lako se vidi da i drugi imaju samo jednu, promotrimo dalje
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
#
#    TransactionAmount (INR)
# 0                     25.0

# %%
occurrences = data.groupby('CustomerID')['CustomerID'].transform('count') #sada ću direktno izabrati nekog tko ima više transakcija
data['occurrences_count'] = occurrences
data[data['occurrences_count'] >= 5]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 193              T194   C4325361    1/1/1800          M      KOLKATA
# 2846            T2847   C7431859      4/2/71          M       MUMBAI
# 4513            T4514   C2833541     10/4/78          M      CHENNAI
# 5590            T5591   C2618678     18/5/92          M    BANGALORE
# 6549            T6550   C3638492     28/3/88          M        VERNA
# ...               ...        ...         ...        ...          ...
# 1040909      T1040910   C4631592      1/8/89          M  GANDHINAGAR
# 1041063      T1041064   C6735715      1/1/72          M    BANGALORE
# 1045312      T1045313   C8137979     24/6/80          M    HYDERABAD
# 1046146      T1046147   C4423377     18/6/74          F       MUMBAI
# 1047721      T1047722   C1434678     22/2/85          M    BANGALORE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 193               133203.58          7/8/16            93946
# 2846               49134.38        21/10/16           213030
# 4513                   6.13         23/9/16           112240
# 5590                7468.45         22/9/16           141027
# 6549               39372.32         25/9/16           201758
# ...                     ...             ...              ...
# 1040909                0.63         18/9/16           150837
# 1041063            89777.85         18/9/16           125524
# 1045312            15865.71         18/9/16            21021
# 1046146            17741.83         18/9/16           103623
# 1047721             8681.41         18/9/16           191351
#
#          TransactionAmount (INR)  occurrences_count
# 193                    100000.00                  5
# 2846                      528.00                  5
# 4513                      900.00                  5
# 5590                     1422.60                  5
# 6549                       40.00                  5
# ...                          ...                ...
# 1040909                   189.00                  5
# 1041063                  1474.00                  5
# 1045312                   550.00                  5
# 1046146                   632.56                  5
# 1047721                  1099.00                  5
#
# [819 rows x 10 columns]

# %%
data[data['CustomerID'] == "C4325361"] #sada smo uzeli prvog koji ima više ili jednako od 5 transakcija
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 193              T194   C4325361    1/1/1800          M      KOLKATA
# 35809          T35810   C4325361      1/5/92          F    HYDERABAD
# 288523        T288524   C4325361     18/5/90          M    BANGALORE
# 755640        T755641   C4325361     30/3/73          M       MUMBAI
# 1029893      T1029894   C4325361    1/1/1800          M      KOLKATA
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 193               133203.58          7/8/16            93946
# 35809              13019.47         30/9/16           193433
# 288523             16441.25         11/8/16           155050
# 755640           3743220.40          1/9/16           191637
# 1029893           157333.33         13/9/16            94608
#
#          TransactionAmount (INR)  occurrences_count
# 193                    100000.00                  5
# 35809                      60.00                  5
# 288523                    165.00                  5
# 755640                   1042.21                  5
# 1029893                100000.00                  5

# %% [markdown]
# As we can observe, the CustomerID is incorrectly assigned, with the same ID showing up with different individuals. Let's attempt to rectify this issue.

# %%
data[data['CustomerDOB'] == "26/11/96"] #promatramo samo one rođene na ovaj datum
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 10128          T10129   C6717025    26/11/96          F         MUMBAI
# 22198          T22199   C6917052    26/11/96          F         MUMBAI
# 31107          T31108   C4717074    26/11/96          F         MUMBAI
# 43250          T43251   C8317081    26/11/96          F         MUMBAI
# 52415          T52416   C6017088    26/11/96          F         MUMBAI
# 67478          T67479   C6717075    26/11/96          F         MUMBAI
# 83143          T83144   C8417083    26/11/96          F         MUMBAI
# 99047          T99048   C8317066    26/11/96          F         MUMBAI
# 249398        T249399   C7986053    26/11/96          M    NAVI MUMBAI
# 253564        T253565   C7686040    26/11/96          M    NAVI MUMBAI
# 319668        T319669   C2686014    26/11/96          M    NAVI MUMBAI
# 417937        T417938   C4420476    26/11/96          M         MUMBAI
# 457910        T457911   C2886032    26/11/96          M    NAVI MUMBAI
# 661374        T661375   C6318571    26/11/96          M  SRIPERUMBUDUR
# 677395        T677396   C5218571    26/11/96          M  SRIPERUMBUDUR
# 745985        T745986   C6640746    26/11/96          F          DEWAS
# 920704        T920705   C5640775    26/11/96          F          DEWAS
# 943577        T943578   C1640728    26/11/96          F          DEWAS
# 973976        T973977   C3440751    26/11/96          F          DEWAS
# 987436        T987437   C2722347    26/11/96          F   STATION PUNE
# 989867        T989868   C4822312    26/11/96          F   STATION PUNE
# 991670        T991671   C1687528    26/11/96          M        CHENNAI
# 1039089      T1039090   C8517050    26/11/96          F         MUMBAI
# 1041176      T1041177   C5317060    26/11/96          F         MUMBAI
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 2                  17874.44          2/8/16           142712
# 10128              17874.44         25/9/16           220458
# 22198              17874.44         23/9/16           132747
# 31107              17874.44         25/9/16           215925
# 43250              17874.44          3/8/16           110021
# 52415              17874.44          3/8/16           171134
# 67478              17874.44          2/8/16           141916
# 83143              17874.44          2/8/16           215000
# 99047              17874.44          1/8/16           211642
# 249398                 9.43          7/8/16           160624
# 253564                 9.43         12/8/16           112423
# 319668                 9.43         15/8/16           215636
# 417937            140239.75         17/8/16           150258
# 457910                 9.43         16/8/16           103805
# 661374              5034.26         31/8/16            14216
# 677395              5034.26         28/8/16            83241
# 745985             19812.05          1/9/16           213150
# 920704             19812.05         11/9/16           101249
# 943577             19812.05         11/9/16           185405
# 973976             19812.05         15/9/16           172223
# 987436              2345.76         15/9/16           200436
# 989867              2345.76         15/9/16           200026
# 991670              3076.29         15/9/16           213624
# 1039089            17874.44         18/9/16           171222
# 1041176            17874.44         18/9/16           143158
#
#          TransactionAmount (INR)  occurrences_count
# 2                         459.00                  1
# 10128                     127.00                  1
# 22198                     130.00                  1
# 31107                     149.83                  1
# 43250                     497.00                  1
# 52415                      45.00                  1
# 67478                     155.00                  1
# 83143                     605.00                  2
# 99047                     320.00                  2
# 249398                     50.00                  1
# 253564                    512.65                  1
# 319668                     80.00                  1
# 417937                   2911.88                  1
# 457910                     50.00                  1
# 661374                     30.00                  1
# 677395                     15.00                  2
# 745985                   2499.00                  1
# 920704                    317.60                  1
# 943577                    449.00                  1
# 973976                    176.05                  2
# 987436                    610.00                  1
# 989867                    899.00                  1
# 991670                     50.00                  1
# 1039089                  7196.00                  2
# 1041176                   660.00                  3

# %% [markdown]
# As we can see, the account balance is the most reliable indicator of individual uniqueness. Let's combine it with the date of birth and gender; this should provide us with distinct individuals.

# %%
data['unique_customer_id'] = data.groupby(['CustomerDOB', 'CustAccountBalance', 'CustGender']).ngroup() + 1 # grupirali smo pa radimo isto da provjerimo je li sve kako treba
occurrences = data.groupby('unique_customer_id')['unique_customer_id'].transform('count')
data['occurrences_count'] = occurrences
data[data['occurrences_count'] >= 5]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender  CustLocation  \
# 0                  T1   C5841053     10/1/94          F    JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M       JHAJJAR
# 2                  T3   C4417068    26/11/96          F        MUMBAI
# 3                  T4   C5342380     14/9/73          F        MUMBAI
# 5                  T6   C1536588     8/10/72          F      ITANAGAR
# ...               ...        ...         ...        ...           ...
# 1048559      T1048560   C2427315    28/10/88          M  PAREL MUMBAI
# 1048560      T1048561   C5028150     24/5/80          M          PUNE
# 1048561      T1048562   C1034220    19/11/92          M     BANGALORE
# 1048562      T1048563   C8020229      8/4/90          M     NEW DELHI
# 1048564      T1048565   C6412354     18/5/89          M     HYDERABAD
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 0                  17819.05          2/8/16           143207
# 1                   2270.69          2/8/16           141858
# 2                  17874.44          2/8/16           142712
# 3                 866503.21          2/8/16           142714
# 5                  53609.20          2/8/16           173940
# ...                     ...             ...              ...
# 1048559             7315.11         18/9/16           184632
# 1048560              464.87         18/9/16           184632
# 1048561             1212.70         18/9/16           184734
# 1048562             7635.19         18/9/16           184824
# 1048564           221757.06         18/9/16           183313
#
#          TransactionAmount (INR)  occurrences_count  unique_customer_id
# 0                           25.0               27.0             19398.0
# 1                        27999.0               12.0            140937.0
# 2                          459.0               11.0            109652.0
# 3                         2060.0               13.0             45892.0
# 5                          676.0               11.0            161328.0
# ...                          ...                ...                 ...
# 1048559                    765.0               14.0            117940.0
# 1048560                   3000.0                5.0            101115.0
# 1048561                   1500.0                5.0             69077.0
# 1048562                    799.0               20.0            163565.0
# 1048564                    770.0               24.0             66196.0
#
# [836960 rows x 11 columns]

# %%
data[data['unique_customer_id'] == 19543.0]
# Out:
#        TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 3042           T3043   C2421285    10/10/77          M      KOLKATA
# 233512       T233513   C7621290    10/10/77          M      KOLKATA
# 242868       T242869   C3421251    10/10/77          M      KOLKATA
# 309248       T309249   C6321246    10/10/77          M      KOLKATA
# 527716       T527717   C8121269    10/10/77          M      KOLKATA
# 541559       T541560   C5721292    10/10/77          M      KOLKATA
# 543509       T543510   C2621230    10/10/77          M      KOLKATA
# 700597       T700598   C3921279    10/10/77          M      KOLKATA
# 765533       T765534   C8721214    10/10/77          M      KOLKATA
#
#         CustAccountBalance TransactionDate  TransactionTime  \
# 3042              92477.53        21/10/16           164706
# 233512            92477.53          7/8/16           180250
# 242868            92477.53          7/8/16           181732
# 309248            92477.53         10/8/16           145512
# 527716            92477.53         24/8/16           193102
# 541559            92477.53         24/8/16           192753
# 543509            92477.53         24/8/16           193903
# 700597            92477.53         30/8/16           122401
# 765533            92477.53          1/9/16           122014
#
#         TransactionAmount (INR)  occurrences_count  unique_customer_id
# 3042                     1326.0                9.0             19543.0
# 233512                   1028.0                9.0             19543.0
# 242868                    270.0                9.0             19543.0
# 309248                   7890.0                9.0             19543.0
# 527716                   2327.0                9.0             19543.0
# 541559                    475.0                9.0             19543.0
# 543509                   1695.0                9.0             19543.0
# 700597                    300.0                9.0             19543.0
# 765533                    642.0                9.0             19543.0

# %% [markdown]
# As we can see, the data is now much more meaningful. Let's replace the CustomerID with the unique_customer_id that we have created.

# %%
data['unique_customer_id'].nunique()
# Out:
# 170816

# %% [markdown]
# From this, we observe that we actually have 170,816 distinct individuals

# %%
data['CustomerID'] = 'C' + (data.groupby(['CustomerDOB', 'CustAccountBalance', 'CustGender'], dropna=False).ngroup() + 1).astype(str).str.zfill(6)
# samo uređujemo unique_customer_id i dodjeljujemo ga CustomerID

# %%
data[data['CustomerID'] == "C019595"]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0                  T1    C019595     10/1/94          F   JAMSHEDPUR
# 85184          T85185    C019595     10/1/94          F   JAMSHEDPUR
# 263767        T263768    C019595     10/1/94          F   JAMSHEDPUR
# 269108        T269109    C019595     10/1/94          F   JAMSHEDPUR
# 296236        T296237    C019595     10/1/94          F   JAMSHEDPUR
# 342910        T342911    C019595     10/1/94          F   JAMSHEDPUR
# 378250        T378251    C019595     10/1/94          F   JAMSHEDPUR
# 383488        T383489    C019595     10/1/94          F   JAMSHEDPUR
# 422326        T422327    C019595     10/1/94          F   JAMSHEDPUR
# 439840        T439841    C019595     10/1/94          F   JAMSHEDPUR
# 448981        T448982    C019595     10/1/94          F   JAMSHEDPUR
# 514447        T514448    C019595     10/1/94          F   JAMSHEDPUR
# 526859        T526860    C019595     10/1/94          F   JAMSHEDPUR
# 589397        T589398    C019595     10/1/94          F   JAMSHEDPUR
# 612065        T612066    C019595     10/1/94          F   JAMSHEDPUR
# 622114        T622115    C019595     10/1/94          F   JAMSHEDPUR
# 705567        T705568    C019595     10/1/94          F   JAMSHEDPUR
# 706807        T706808    C019595     10/1/94          F   JAMSHEDPUR
# 710845        T710846    C019595     10/1/94          F   JAMSHEDPUR
# 741781        T741782    C019595     10/1/94          F   JAMSHEDPUR
# 770755        T770756    C019595     10/1/94          F   JAMSHEDPUR
# 771952        T771953    C019595     10/1/94          F   JAMSHEDPUR
# 785885        T785886    C019595     10/1/94          F   JAMSHEDPUR
# 875688        T875689    C019595     10/1/94          F   JAMSHEDPUR
# 1009956      T1009957    C019595     10/1/94          F   JAMSHEDPUR
# 1035527      T1035528    C019595     10/1/94          F   JAMSHEDPUR
# 1044705      T1044706    C019595     10/1/94          F   JAMSHEDPUR
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 0                  17819.05          2/8/16           143207
# 85184              17819.05          1/8/16           153632
# 263767             17819.05         12/8/16           110709
# 269108             17819.05         12/8/16           200204
# 296236             17819.05         11/8/16           195839
# 342910             17819.05         15/8/16           210915
# 378250             17819.05         13/8/16            64329
# 383488             17819.05         13/8/16            95839
# 422326             17819.05         17/8/16           122508
# 439840             17819.05         16/8/16           105206
# 448981             17819.05         16/8/16           190026
# 514447             17819.05         19/8/16           182729
# 526859             17819.05         24/8/16           214814
# 589397             17819.05         23/8/16           162638
# 612065             17819.05         26/8/16           221840
# 622114             17819.05         28/8/16              642
# 705567             17819.05          3/9/16            94742
# 706807             17819.05          3/9/16            94029
# 710845             17819.05          3/9/16           163032
# 741781             17819.05          1/9/16           220852
# 770755             17819.05          6/9/16           204220
# 771952             17819.05          6/9/16           204617
# 785885             17819.05          6/9/16            90623
# 875688             17819.05          8/9/16           230502
# 1009956            17819.05         14/9/16           233012
# 1035527            17819.05         18/9/16           155212
# 1044705            17819.05         18/9/16            90819
#
#          TransactionAmount (INR)  occurrences_count  unique_customer_id
# 0                           25.0               27.0             19398.0
# 85184                      270.0               27.0             19398.0
# 263767                     130.0               27.0             19398.0
# 269108                      50.0               27.0             19398.0
# 296236                      37.0               27.0             19398.0
# 342910                      25.0               27.0             19398.0
# 378250                     198.0               27.0             19398.0
# 383488                       4.0               27.0             19398.0
# 422326                     128.0               27.0             19398.0
# 439840                     128.0               27.0             19398.0
# 448981                      25.0               27.0             19398.0
# 514447                     270.0               27.0             19398.0
# 526859                     199.0               27.0             19398.0
# 589397                      25.0               27.0             19398.0
# 612065                      25.0               27.0             19398.0
# 622114                       4.0               27.0             19398.0
# 705567                      30.0               27.0             19398.0
# 706807                       9.0               27.0             19398.0
# 710845                      28.0               27.0             19398.0
# 741781                      25.0               27.0             19398.0
# 770755                      28.0               27.0             19398.0
# 771952                      25.0               27.0             19398.0
# 785885                      45.0               27.0             19398.0
# 875688                      28.0               27.0             19398.0
# 1009956                      4.0               27.0             19398.0
# 1035527                    128.0               27.0             19398.0
# 1044705                    270.0               27.0             19398.0

# %% [markdown]
# Now that the data makes sense in this arrangement, we can discard the last two columns.

# %%
data = data.drop(columns=['occurrences_count', 'unique_customer_id'], inplace=False)
data.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1    C019595     10/1/94          F   JAMSHEDPUR
# 1            T2    C141602      4/4/57          M      JHAJJAR
# 2            T3    C110205    26/11/96          F       MUMBAI
# 3            T4    C046214     14/9/73          F       MUMBAI
# 4            T5    C100959     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %% [markdown]
# Let's examine how many rows contain NA (Not Available) data.

# %%
rows_with_missing = data[data.isna().any(axis=1)]
len(rows_with_missing)
# Out:
# 6953

# %% [markdown]
# Since they constitute a small portion of the overall data, it is best to remove them. If there were more, we could consider filling them with average values to avoid losing information (although this might be difficult to do with for dates).

# %%
data = data.dropna()

# %%
rows_with_missing = data[data.isna().any(axis=1)] # provjeravamo je li uspjelo
len(rows_with_missing)
# Out:
# 0

# %% [markdown]
# Now, we only need to organize the dates.

# %%
df = pd.DataFrame(data)

def count_digits(number):
    return len(str(number))

df['digit_count'] = df['TransactionTime'].apply(count_digits)
df[df['digit_count'] == 3]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender  CustLocation  \
# 5121            T5122    C034608     12/5/63          M       CHENNAI
# 5125            T5126    C140709     4/12/95          F          DURG
# 21304          T21305    C129372      3/4/94          M      DINDIGUL
# 35039          T35040    C168345     9/12/90          M     BANGALORE
# 35040          T35041    C170899      9/8/85          M       HOOGHLY
# ...               ...        ...         ...        ...           ...
# 1046769      T1046770    C106807     25/5/86          F         DELHI
# 1047011      T1047012    C027327    11/10/90          M         DELHI
# 1047012      T1047013    C081627     20/3/82          F  BASSEIN ROAD
# 1047013      T1047014    C069808    19/12/90          M        MUMBAI
# 1047015      T1047016    C133902     30/4/92          F      DEHRADUN
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 5121              349954.18         22/9/16              633
# 5125                 401.44         22/9/16              400
# 21304                 70.09         22/9/16              113
# 35039              19298.99         27/9/16              357
# 35040             100242.39         27/9/16              333
# ...                     ...             ...              ...
# 1046769           475834.36         18/9/16              144
# 1047011            13538.00         18/9/16              908
# 1047012             3911.36         18/9/16              210
# 1047013             3684.14         18/9/16              220
# 1047015             1044.73         18/9/16              439
#
#          TransactionAmount (INR)  digit_count
# 5121                     8098.00            3
# 5125                      110.00            3
# 21304                      10.00            3
# 35039                    1538.81            3
# 35040                   11994.00            3
# ...                          ...          ...
# 1046769                    72.00            3
# 1047011                   635.00            3
# 1047012                  1407.00            3
# 1047013                   960.00            3
# 1047015                    52.00            3
#
# [3480 rows x 10 columns]

# %% [markdown]
# As we can see, TransactionTime is actually a number and it is not padded with zeros to represent midnight. We will need to convert it to a string and manually pad it with zeros. Once we do that, we can concatenate it with TransactionDate and convert the whole combination into the DateTime type, representing the date and time of the transaction.

# %%
data['TransactionTime'] = data['TransactionTime'].astype(str).str.zfill(6) # punimo nulama
data['concatenated'] = data['TransactionDate'] + data['TransactionTime'] # spajamo
data['TransactionTime'] = pd.to_datetime(data['concatenated'], format='%d/%m/%y%H%M%S')
data = data.drop(columns=['TransactionDate', 'concatenated'], inplace=False)

# %% [markdown]
# We have successfully merged the time and date into a DateTime format column. Let's now proceed to converting the date of birth values to DateTime.

# %% [markdown]
# It's evident that those "born" in 1800 represent cases where the date is unknown. We can remove them (out of over a million transactions, they account for approximately 57,000, slightly more than half a percent of the data).

# %%
data = data[data['CustomerDOB'] != "1/1/1800"]

# %%
data['CustomerDOB'] = pd.to_datetime(data['CustomerDOB'], format='%d/%m/%y')

# %%
date_string = "1 1 2050"
date_object = pd.to_datetime(date_string, format="%d %m %Y")

data[data['CustomerDOB'] > date_object]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender      CustLocation  \
# 1                  T2    C141602  2057-04-04          M           JHAJJAR
# 15                T16    C024701  2068-07-10          F         NEW DELHI
# 30                T31    C085343  2067-01-21          F         NEW DELHI
# 51                T52    C107671  2066-07-25          M              PUNE
# 79                T80    C106540  2067-05-25          M             DELHI
# ...               ...        ...         ...        ...               ...
# 1048467      T1048468    C166888  2060-01-09          F         NEW DELHI
# 1048491      T1048492    C019006  2059-01-10          M  KHAR WEST MUMBAI
# 1048495      T1048496    C018495  2062-09-01          F           BHIWADI
# 1048496      T1048497    C159156  2067-05-07          F            NAGPUR
# 1048500      T1048501    C016483  2051-07-01          M             THANE
#
#          CustAccountBalance     TransactionTime  TransactionAmount (INR)  \
# 1                   2270.69 2016-08-02 14:18:58                 27999.00
# 15                  1283.12 2016-08-01 12:57:25                   250.00
# 30                298461.05 2016-08-03 16:06:42                   500.00
# 51                  9956.49 2016-08-05 13:31:41                   145.00
# 79                257966.29 2016-08-01 20:42:52                   195.64
# ...                     ...                 ...                      ...
# 1048467           141037.47 2016-09-18 09:19:04                   568.00
# 1048491            10793.51 2016-09-18 18:24:22                  2102.86
# 1048495             7724.64 2016-09-18 18:15:47                   296.00
# 1048496             7597.12 2016-09-18 18:17:41                  1736.00
# 1048500            42695.04 2016-09-18 18:21:22                  1465.00
#
#          digit_count
# 1                  6
# 15                 6
# 30                 6
# 51                 6
# 79                 6
# ...              ...
# 1048467            5
# 1048491            6
# 1048495            6
# 1048496            6
# 1048500            6
#
# [48027 rows x 9 columns]

# %% [markdown]
# As observed above, if we directly apply the pd.to_datetime function, it will convert all dates in the format like 1/1/55 before 1968 to 2055 instead of 1955. We need to pay special attention to this. Therefore, for clients born after the first transaction date minus 16 (indicating the earliest possible time a person can have an account), we should subtract 100 years from their birthdate.

# %%
threshold = min(data['TransactionTime']) - pd.DateOffset(years=16)
data.loc[data['CustomerDOB'] > threshold, 'CustomerDOB'] -= pd.DateOffset(years=100)

# %%
data.sort_values(by='CustomerDOB')
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 161452        T161453    C130842  1900-08-03          F   GANDHIDHAM
# 244423        T244424    C130842  1900-08-03          F   GANDHIDHAM
# 176840        T176841    C170709  1900-08-09          M  NAVI MUMBAI
# 680063        T680064    C170709  1900-08-09          M  NAVI MUMBAI
# 842470        T842471    C040785  1900-08-13          M    NEW DELHI
# ...               ...        ...         ...        ...          ...
# 235978        T235979    C134978  2000-07-30          M        DELHI
# 1016493      T1016494    C134978  2000-07-30          M        DELHI
# 156677        T156678    C017795  2000-08-01          F    NEW DELHI
# 155205        T155206    C017795  2000-08-01          F    NEW DELHI
# 615258        T615259    C017795  2000-08-01          F    NEW DELHI
#
#          CustAccountBalance     TransactionTime  TransactionAmount (INR)  \
# 161452             64163.84 2016-08-04 15:29:32                  2000.00
# 244423             64163.84 2016-08-07 18:52:27                  5000.00
# 176840             59058.67 2016-08-04 21:45:06                   893.14
# 680063             59058.67 2016-08-30 21:30:29                   883.06
# 842470               531.22 2016-09-09 13:27:03                   100.00
# ...                     ...                 ...                      ...
# 235978             58175.37 2016-08-07 14:35:01                    49.00
# 1016493            58175.37 2016-09-14 21:32:52                    30.00
# 156677              2363.51 2016-09-03 15:20:13                   300.00
# 155205              2363.51 2016-09-03 14:39:39                   705.00
# 615258              2363.51 2016-08-27 18:41:58                   915.00
#
#          digit_count
# 161452             6
# 244423             6
# 176840             6
# 680063             6
# 842470             6
# ...              ...
# 235978             6
# 1016493            6
# 156677             6
# 155205             6
# 615258             6
#
# [985322 rows x 9 columns]

# %% [markdown]
# It's somewhat illogical to have individuals born in 1900 conducting transactions in 2016, but it's equally illogical to have those born in 2000 making transactions with less than 16 years of age. Therefore, we identify another potential inconsistency in the data. The only remaining tasks are to remove digit_count and transactions with zero amounts.

# %%
data = data.drop(columns=['digit_count'], inplace=False)
data = data[data['TransactionAmount (INR)'] != 0]

# %% [markdown]
# We have finally cleaned the data. Let's take a look now.

# %%
data.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1    C019595  1994-01-10          F   JAMSHEDPUR
# 1            T2    C141602  1957-04-04          M      JHAJJAR
# 2            T3    C110205  1996-11-26          F       MUMBAI
# 3            T4    C046214  1973-09-14          F       MUMBAI
# 4            T5    C100959  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance     TransactionTime  TransactionAmount (INR)
# 0            17819.05 2016-08-02 14:32:07                     25.0
# 1             2270.69 2016-08-02 14:18:58                  27999.0
# 2            17874.44 2016-08-02 14:27:12                    459.0
# 3           866503.21 2016-08-02 14:27:14                   2060.0
# 4             6714.43 2016-08-02 18:11:56                   1762.5

# %% [markdown]
# # **1. How does the average transaction value and sum of transactions vary over time?**

# %%
grouped_data = data.groupby(data['TransactionTime'].dt.date)['TransactionAmount (INR)'].mean()
grouped_data.plot(kind='line', rot=45)
plt.xlabel('Dani (od 1.8.2016. do 21.10.2016.)')
plt.ylabel('Prosjek transakcija')
plt.title('Prosjek transakcija po danima')
plt.show()

# %%
grouped_data = data.groupby(data['TransactionTime'].dt.date)['TransactionAmount (INR)'].sum()
grouped_data.plot(kind='line', rot=45)
plt.xlabel('Dani (od 1.8.2016. do 21.10.2016.)')
plt.ylabel('Zbroj transakcija')
plt.title('Zbroj transakcija po danima')
plt.show()

# %% [markdown]
# By the middle of September, there is a significant drop in the total number of transactions, and the entire month of October remains low. This likely makes sense as people return from vacations and start working and saving again.

# %% [markdown]
# # **2. As time progresses, the data becomes fragmented. How can we fill in the "gaps," and what method can be employed for this purpose?**

# %% [markdown]
# Let's try to fill in the time gaps using a time series approach (in October, we only have data for two dates).

# %%
grouped_data = grouped_data.reset_index() # pretvaramo Series objekt u DataFrame i postavljamo nazive stupaca tako da odgovaraju Prophet biblioteci
grouped_data.columns = ['ds', 'y']

# %%
grouped_data[:-2] #promotrimo kako će popuniti deseti mjesec i hoće li se poklopiti s vrijednostima koje imamo
# Out:
#             ds            y
# 0   2016-08-01  26001637.35
# 1   2016-08-02  26669859.07
# 2   2016-08-03  26762592.11
# 3   2016-08-04  30912733.49
# 4   2016-08-05  30628121.26
# 5   2016-08-06  42429271.14
# 6   2016-08-07  40070110.27
# 7   2016-08-08  25856765.43
# 8   2016-08-09  28696601.40
# 9   2016-08-10  27331121.29
# 10  2016-08-11  27528196.63
# 11  2016-08-12  29293138.15
# 12  2016-08-13  40630166.14
# 13  2016-08-14  41219815.57
# 14  2016-08-15  39399359.00
# 15  2016-08-16  27665180.46
# 16  2016-08-17  28217631.67
# 17  2016-08-18  25631185.73
# 18  2016-08-19  22351725.89
# 19  2016-08-20  29817607.99
# 20  2016-08-21  30170820.60
# 21  2016-08-22  26013740.53
# 22  2016-08-23  22338285.29
# 23  2016-08-24  24899431.90
# 24  2016-08-25  24146132.42
# 25  2016-08-26  22504030.75
# 26  2016-08-27  31168126.26
# 27  2016-08-28  28211360.99
# 28  2016-08-29  19621770.85
# 29  2016-08-30  21808994.04
# 30  2016-08-31  24702245.94
# 31  2016-09-01  27780337.62
# 32  2016-09-02  31903050.96
# 33  2016-09-03  41080543.83
# 34  2016-09-04  41814273.32
# 35  2016-09-05  29532526.50
# 36  2016-09-06  25566818.76
# 37  2016-09-07  26177644.95
# 38  2016-09-08  29185940.45
# 39  2016-09-09  28729934.74
# 40  2016-09-10  35212848.68
# 41  2016-09-11  37783474.15
# 42  2016-09-12  26392616.35
# 43  2016-09-13  25976747.63
# 44  2016-09-14  25443983.49
# 45  2016-09-15  24896635.33
# 46  2016-09-18  20955413.77
# 47  2016-09-22  10009505.25
# 48  2016-09-23   3942721.94
# 49  2016-09-25  11074148.67
# 50  2016-09-26  16684743.67
# 51  2016-09-27   8729508.27
# 52  2016-09-30   2874618.33

# %%
from prophet import Prophet
m = Prophet()
m.fit(grouped_data[:-2])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfcwlasm5/410u2mhe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfcwlasm5/3aihapvy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63319', 'data', 'file=/tmp/tmpfcwlasm5/410u2mhe.json', 'init=/tmp/tmpfcwlasm5/3aihapvy.json', 'output', 'file=/tmp/tmpfcwlasm5/prophet_modelh_azw5ui/prophet_model-20231230113132.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 11:31:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:31:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
grouped_data = data.groupby(data['TransactionTime'].dt.date)['TransactionAmount (INR)'].sum()
ax = grouped_data.plot(kind='line', rot = 45, color = "red") # rot = 45 znači da rotiramo 45 stupnjeva
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
fig = m.plot(forecast, ax=ax, xlabel = "Dan", ylabel = "Suma transakcija (u desecima milijuna rupija)")

# %% [markdown]
# Ignoring the sum of transactions on October 16, which appears to be an error (as it is unreasonably low), we notice that the last data point on October 21 aligns quite well with the assumed trend.

# %% [markdown]
# # **3. Is there a weekly pattern in transactions?**

# %%
fig1 = m.plot_components(forecast)

# %% [markdown]
# Examining the weekly component, we observe that spending is highest during the weekends, while it decreases during the weekdays. This makes sense, as people find it more challenging to engage in shopping activities during the workweek.

# %% [markdown]
# # **4. On average, how many transactions does a client conduct?**

# %%
transaction_by_customer = data.groupby(data['CustomerID'])['TransactionID'].count().reset_index()
transaction_by_customer
# Out:
#        CustomerID  TransactionID
# 0         C000001              3
# 1         C000002              2
# 2         C000003              8
# 3         C000004              1
# 4         C000005              1
# ...           ...            ...
# 162248    C171598              9
# 162249    C171599              3
# 162250    C171600              3
# 162251    C171601              1
# 162252    C171602             36
#
# [162253 rows x 2 columns]

# %% [markdown]
# As we can see, we lost a portion of clients, specifically those for whom we did not have the year of birth, those with only zero-value transactions, or those with unknown data. From over 170,000 clients, this constitutes around 9,000 individuals, and we could have discarded their data.

# %%
transaction_by_customer['TransactionID'].mean()
# Out:
# 6.068387025201383

# %% [markdown]
# So, on average, a person carries out around 6 transactions. Let's examine the extremes.

# %% [markdown]
# # **5. Are there clients who perform excessively large transactions or an exceptionally high number of small transactions? What conclusions can be drawn about them?**

# %%
len(transaction_by_customer[transaction_by_customer['TransactionID'] > 100])
# Out:
# 47

# %% [markdown]
# So, we have 47 clients who had over 100 transactions during this period.

# %%
data[data['CustomerID'].isin(transaction_by_customer[transaction_by_customer['TransactionID'] > 100]['CustomerID'])]['TransactionAmount (INR)'].sum()/47
# Out:
# 165730.42617021274

# %% [markdown]
# This is the average value across all transactions for these 47 individuals.

# %%
transaction_amount_by_customer = data.groupby(data['CustomerID'])['TransactionAmount (INR)'].sum()

# %%
transaction_amount_by_customer.mean()
# Out:
# 8820.215664795103

# %% [markdown]
# As we can see, this is significantly higher than the average total transaction value during this period. Let's take a closer look at the client with the highest number of transactions.

# %%
data[data['CustomerID'] == "C155717"].sort_values(by="TransactionTime")
# Out:
#       TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 68126        T68127    C155717  1991-08-06          M       MEERUT
# 69265        T69266    C155717  1991-08-06          M       MEERUT
# 67247        T67248    C155717  1991-08-06          M       MEERUT
# 70026        T70027    C155717  1991-08-06          M       MEERUT
# 67494        T67495    C155717  1991-08-06          M       MEERUT
# ...             ...        ...         ...        ...          ...
# 17918        T17919    C155717  1991-08-06          M       MEERUT
# 28539        T28540    C155717  1991-08-06          M       MEERUT
# 12113        T12114    C155717  1991-08-06          M       MEERUT
# 35149        T35150    C155717  1991-08-06          M       MEERUT
# 37397        T37398    C155717  1991-08-06          M       MEERUT
#
#        CustAccountBalance     TransactionTime  TransactionAmount (INR)
# 68126            45856.24 2016-08-02 09:03:29                   5303.0
# 69265            45856.24 2016-08-02 09:06:25                   5303.0
# 67247            45856.24 2016-08-02 09:08:37                   5303.0
# 70026            45856.24 2016-08-02 13:05:18                    655.0
# 67494            45856.24 2016-08-02 13:08:01                    655.0
# ...                   ...                 ...                      ...
# 17918            45856.24 2016-09-26 16:02:22                  10993.0
# 28539            45856.24 2016-09-26 21:37:19                   3875.0
# 12113            45856.24 2016-09-26 21:40:39                   3875.0
# 35149            45856.24 2016-09-30 14:14:08                    655.0
# 37397            45856.24 2016-09-30 14:29:55                    655.0
#
# [538 rows x 8 columns]

# %% [markdown]
# As we can see, the transactions for this client are very frequent and substantial. Perhaps it would be advisable to further investigate this client. Let's now examine clients with exceptionally large transactions.

# %%
max(data['TransactionAmount (INR)'])
# Out:
# 1560034.99

# %%
data['TransactionAmount (INR)'].mean()
# Out:
# 1453.4695345180946

# %% [markdown]
# So, large transactions would be those exceeding 500,000.

# %%
len(data[data['TransactionAmount (INR)'] > 500000])
# Out:
# 15

# %% [markdown]
# We have 15 such transactions. Let's see what they are and which clients executed them.

# %%
data[data['TransactionAmount (INR)'] > 500000]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 56540          T56541    C061754  1985-05-17          F      KOLKATA
# 152735        T152736    C100175  1983-12-24          M       MUMBAI
# 173291        T173292    C038075  1989-11-13          M    NEW DELHI
# 253378        T253379    C018190  1988-08-01          M        NOIDA
# 286978        T286979    C123335  1981-11-29          M    NEW DELHI
# 356306        T356307    C144408  1969-01-05          F        DELHI
# 399117        T399118    C106605  1976-05-25          M      GURGAON
# 421473        T421474    C137861  1977-05-31          M     LUDHIANA
# 532036        T532037    C058284  1976-08-16          M    NEW DELHI
# 579014        T579015    C161687  1978-01-08          F         PUNE
# 749353        T749354    C020819  1969-12-10          M       MUMBAI
# 777251        T777252    C104378  1966-11-25          F       MUMBAI
# 846924        T846925    C068250  1988-09-18          F        NOIDA
# 1021537      T1021538    C095055  1988-10-23          M        DELHI
# 1036138      T1036139    C095338  1983-11-23          F    NEW DELHI
#
#          CustAccountBalance     TransactionTime  TransactionAmount (INR)
# 56540              14177.65 2016-08-03 19:00:43                720001.16
# 152735              9324.35 2016-08-05 20:08:14                561001.00
# 173291            136294.60 2016-08-04 20:21:32                600003.45
# 253378             13357.20 2016-08-12 12:11:22                520009.87
# 286978             38329.46 2016-08-11 18:34:40                525003.83
# 356306             38735.17 2016-08-14 18:51:41                569500.27
# 399117             42487.89 2016-08-18 13:27:11               1560034.99
# 421473            320344.55 2016-08-17 12:19:55                514320.00
# 532036             83608.10 2016-08-23 20:27:59                991132.22
# 579014             98660.33 2016-08-22 20:49:02               1380002.88
# 749353          61382213.47 2016-09-02 23:37:15                724122.00
# 777251           1629701.75 2016-09-06 11:49:07                543699.36
# 846924             29198.46 2016-09-09 13:02:27                600008.32
# 1021537             9462.34 2016-09-13 14:44:49                550004.34
# 1036138            39127.54 2016-09-18 13:32:00                510005.16

# %%
data[data['CustomerID'] == "C106605"]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 2123            T2124    C106605  1976-05-25          M      GURGAON
# 152497        T152498    C106605  1976-05-25          M      GURGAON
# 163394        T163395    C106605  1976-05-25          M      GURGAON
# 280733        T280734    C106605  1976-05-25          M      GURGAON
# 399117        T399118    C106605  1976-05-25          M      GURGAON
# 401033        T401034    C106605  1976-05-25          M      GURGAON
# 838547        T838548    C106605  1976-05-25          M      GURGAON
# 881369        T881370    C106605  1976-05-25          M      GURGAON
# 914649        T914650    C106605  1976-05-25          M      GURGAON
# 932882        T932883    C106605  1976-05-25          M      GURGAON
# 938068        T938069    C106605  1976-05-25          M      GURGAON
# 940872        T940873    C106605  1976-05-25          M      GURGAON
# 964774        T964775    C106605  1976-05-25          M      GURGAON
# 1009363      T1009364    C106605  1976-05-25          M      GURGAON
# 1019155      T1019156    C106605  1976-05-25          M      GURGAON
#
#          CustAccountBalance     TransactionTime  TransactionAmount (INR)
# 2123               42487.89 2016-10-21 20:32:22                  1097.00
# 152497             42487.89 2016-08-05 19:35:10                  2280.00
# 163394             42487.89 2016-08-04 13:28:14                  1279.00
# 280733             42487.89 2016-08-11 09:53:26                   380.00
# 399117             42487.89 2016-08-18 13:27:11               1560034.99
# 401033             42487.89 2016-08-18 13:27:35                   156.00
# 838547             42487.89 2016-09-09 18:59:22                   206.00
# 881369             42487.89 2016-09-07 20:37:40                   230.00
# 914649             42487.89 2016-09-12 21:01:02                   330.00
# 932882             42487.89 2016-09-11 15:36:54                   965.00
# 938068             42487.89 2016-09-11 20:17:19                   400.00
# 940872             42487.89 2016-09-11 20:28:49                   420.00
# 964774             42487.89 2016-09-10 13:39:56                   690.00
# 1009363            42487.89 2016-09-14 19:52:34                   464.99
# 1019155            42487.89 2016-09-13 19:15:40                   200.00

# %%
data[data['CustomerID'] == "C161687"]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 170473        T170474    C161687  1978-01-08          F         PUNE
# 172822        T172823    C161687  1978-01-08          F         PUNE
# 175442        T175443    C161687  1978-01-08          F         PUNE
# 195978        T195979    C161687  1978-01-08          F         PUNE
# 197376        T197377    C161687  1978-01-08          F         PUNE
# 259113        T259114    C161687  1978-01-08          F         PUNE
# 343313        T343314    C161687  1978-01-08          F         PUNE
# 363943        T363944    C161687  1978-01-08          F         PUNE
# 409809        T409810    C161687  1978-01-08          F         PUNE
# 413198        T413199    C161687  1978-01-08          F         PUNE
# 430515        T430516    C161687  1978-01-08          F         PUNE
# 456564        T456565    C161687  1978-01-08          F         PUNE
# 550604        T550605    C161687  1978-01-08          F         PUNE
# 579014        T579015    C161687  1978-01-08          F         PUNE
# 623566        T623567    C161687  1978-01-08          F         PUNE
# 635000        T635001    C161687  1978-01-08          F         PUNE
# 698185        T698186    C161687  1978-01-08          F         PUNE
# 720040        T720041    C161687  1978-01-08          F         PUNE
# 748838        T748839    C161687  1978-01-08          F         PUNE
# 815271        T815272    C161687  1978-01-08          F         PUNE
# 827959        T827960    C161687  1978-01-08          F         PUNE
# 832115        T832116    C161687  1978-01-08          F         PUNE
# 876808        T876809    C161687  1978-01-08          F         PUNE
# 917920        T917921    C161687  1978-01-08          F         PUNE
# 932283        T932284    C161687  1978-01-08          F         PUNE
# 935030        T935031    C161687  1978-01-08          F         PUNE
# 1029104      T1029105    C161687  1978-01-08          F         PUNE
# 1033036      T1033037    C161687  1978-01-08          F         PUNE
#
#          CustAccountBalance     TransactionTime  TransactionAmount (INR)
# 170473             98660.33 2016-08-04 19:11:06                  1300.00
# 172822             98660.33 2016-08-04 19:31:25                   391.00
# 175442             98660.33 2016-08-04 20:36:57                  1500.00
# 195978             98660.33 2016-08-09 19:59:18                  1262.60
# 197376             98660.33 2016-08-09 20:09:08                  4150.00
# 259113             98660.33 2016-08-12 16:39:05                  3680.00
# 343313             98660.33 2016-08-14 12:28:18                  5100.23
# 363943             98660.33 2016-08-14 16:57:20                  1696.26
# 409809             98660.33 2016-08-18 20:25:06                   957.24
# 413198             98660.33 2016-08-18 19:33:31                  1000.00
# 430515             98660.33 2016-08-17 17:58:07                  1200.00
# 456564             98660.33 2016-08-21 10:11:48                   200.00
# 550604             98660.33 2016-08-23 19:13:07                  2753.00
# 579014             98660.33 2016-08-22 20:49:02               1380002.88
# 623566             98660.33 2016-08-28 09:59:21                   404.00
# 635000             98660.33 2016-08-29 18:56:18                   890.00
# 698185             98660.33 2016-08-31 20:36:09                  1000.00
# 720040             98660.33 2016-09-03 20:52:39                   579.00
# 748838             98660.33 2016-09-01 20:47:15                   542.00
# 815271             98660.33 2016-09-04 20:19:27                   759.50
# 827959             98660.33 2016-09-04 11:45:29                  1263.00
# 832115             98660.33 2016-09-04 11:49:06                  2308.00
# 876808             98660.33 2016-09-08 19:47:46                  1057.70
# 917920             98660.33 2016-09-12 21:06:51                   789.56
# 932283             98660.33 2016-09-11 14:39:58                  1200.00
# 935030             98660.33 2016-09-11 13:08:00                   439.00
# 1029104            98660.33 2016-09-13 11:49:00                  1200.00
# 1033036            98660.33 2016-09-18 17:36:52                  2185.00

# %% [markdown]
# As we can see, they don't have an exceptionally above-average number of transactions, but they do have quite substantial transaction amounts. It would be a good idea to investigate the purpose of these large transactions.

# %% [markdown]
# So, perhaps none of the clients have done anything wrong, but when transactions are quite anomalous compared to average behavior, it's not a bad idea to conduct additional checks.

# %% [markdown]
# # **6. What is the correlation between transaction size and account balance?**

# %%
transaction_amount_by_balance = data.groupby(data['CustAccountBalance'])['TransactionAmount (INR)'].sum().reset_index()
transaction_amount_by_balance
# Out:
#         CustAccountBalance  TransactionAmount (INR)
# 0             0.000000e+00               4440991.49
# 1             1.000000e-02                360432.84
# 2             2.000000e-02                 67293.36
# 3             3.000000e-02                 25621.99
# 4             4.000000e-02                 80200.42
# ...                    ...                      ...
# 152785        5.099967e+07                 52289.68
# 152786        6.138221e+07                724122.00
# 152787        6.979933e+07                265190.04
# 152788        8.224463e+07                 76885.36
# 152789        1.150355e+08                 63917.32
#
# [152790 rows x 2 columns]

# %%
transaction_amount_by_balance.corr()
# Out:
#                          CustAccountBalance  TransactionAmount (INR)
# CustAccountBalance                  1.00000                  0.06817
# TransactionAmount (INR)             0.06817                  1.00000

# %% [markdown]
# As we can see, the correlation is almost zero. Therefore, the data does not exhibit any significant relationship.

# %% [markdown]
# Let's examine the differences by gender, city, and age.

# %% [markdown]
# # **7. Can we group them by gender? Is there a significant difference in the average transaction amount between genders?**

# %%
transactions_by_males = data[data['CustGender'] == "M"]['TransactionAmount (INR)']
transactions_by_females = data[data['CustGender'] == "F"]['TransactionAmount (INR)']

# %% [markdown]
# We will assume the independence of the data and check for normal distribution of the sample.

# %%
import scipy.stats as stats
import seaborn as sns
import random

# %%
transactions_by_males_sample = random.sample(sorted(transactions_by_males), 10000)
transactions_by_females_sample = random.sample(sorted(transactions_by_females), 10000)

# %% [markdown]
# We will use only samples from the dataset for ease of plotting.

# %%
fig, axes = plt.subplots(1, 2, figsize=(25, 10), sharey=True)

statistics, pvalue = stats.normaltest(transactions_by_females_sample)
sns.histplot(transactions_by_females_sample, stat='density', ax=axes[0])

statistics1, pvalue1 = stats.normaltest(transactions_by_males_sample)
sns.histplot(transactions_by_males_sample, stat='density', ax=axes[1])
# Out:
# <Axes: ylabel='Density'>

# %%
pvalue
# Out:
# 0.0

# %%
pvalue1
# Out:
# 0.0

# %% [markdown]
# As we can see, the data is not normally distributed. Let's check if they follow a chi-square distribution using the Kolmogorov-Smirnov test, as they appear to be so.

# %%
from scipy.stats import kstest

for i in range(1, 5000):
  ks_statistic, p_value = kstest(transactions_by_females_sample, 'chi2', args=(i,))
  if p_value > 0.01:
    print(i)

# %% [markdown]
# We do not know which degrees of freedom to use, so we tried from 1 to 5000, and for none of them is the p-value higher than 0.01. Therefore, we conclude that it is not chi-square distributed and probably does not follow any known distribution. It is worth noting that due to the sample size (tens of thousands in both samples), we can use the z-test because of the central limit theorem. However, due to the unknown variance of the total population, we will use the t-test. Another reason is that the Mann-Whitney test is unstable for very large samples.

# %%
from scipy.stats import ttest_ind
t_statistic, p_value = ttest_ind(transactions_by_females, transactions_by_males)
p_value
# Out:
# 9.621054067943416e-15

# %% [markdown]
# The p-value is very small, so we can reject the hypothesis of equal means for any relevant level of significance.

# %%
transactions_by_females.mean()
# Out:
# 1655.7337531567446

# %%
transactions_by_males.mean()
# Out:
# 1543.5643777774874

# %% [markdown]
# So, on average, women have larger transactions, and the difference is statistically significant.

# %% [markdown]
# # **8. Can we group them by age? Is there a significant difference in the average transaction amount among different generations?**

# %% [markdown]
# We will divide them into groups of 16-25, 25-45, 45-65, 65+, and check if there are statistically significant differences in the transaction amounts among them.

# %%
data['TransactionTime'].max()
# Out:
# Timestamp('2016-10-21 22:48:48')

# %%
data['age'] = (data['TransactionTime'].max() - data['CustomerDOB']).astype('<m8[Y]') # oduzimanje daje dane, a astype pretvara u godine
bins = [16, 25, 45, 65, float('inf')]
labels = ['16-25', '25-45', '45-65', '65+']
data['age_category'] = pd.cut(data['age'], bins=bins, labels=labels, right=False) # right = False znači da su intervali zatvoreni slijeva

# %% [markdown]
# After adding these categories, let's separate the data by categories.

# %%
transactions_by_16_25 = data[data['age_category'] == "16-25"]['TransactionAmount (INR)']
transactions_by_25_45 = data[data['age_category'] == "25-45"]['TransactionAmount (INR)']
transactions_by_45_65 = data[data['age_category'] == "45-65"]['TransactionAmount (INR)']
transactions_by_65 = data[data['age_category'] == "65+"]['TransactionAmount (INR)']

# %% [markdown]
# We will use the ANOVA test to test the equality of means across multiple groups. The null hypothesis is that all means are equal, and the alternative hypothesis is that at least one is different from the others.

# %%
f_statistic, p_value = stats.f_oneway(transactions_by_16_25, transactions_by_25_45, transactions_by_45_65, transactions_by_65)
print(str(f_statistic) + "\n" + str(p_value))
# Out:
# 2414.7095505504894
# 0.0

# %% [markdown]
# As we can see, the statistic is very large, and the p-value is extremely small. We conclude that there is a significant generational difference. Let's now check if there are at least two generations that are similar in transaction amounts.

# %%
means_by_category = data.groupby('age_category')['TransactionAmount (INR)'].mean()
print(means_by_category)
# Out:
# age_category
# 16-25     830.167164
# 25-45    1473.269311
# 45-65    2979.774594
# 65+      3509.391055
# Name: TransactionAmount (INR), dtype: float64

# %% [markdown]
# As we can see, the oldest individuals have the highest average transaction amounts, while the youngest have the lowest, and the differences among all generations are significant.

# %% [markdown]
# # **9. What is the number of transactions per city?**

# %%
data['CustLocation']
# Out:
# 0             JAMSHEDPUR
# 1                JHAJJAR
# 2                 MUMBAI
# 3                 MUMBAI
# 4            NAVI MUMBAI
#                ...
# 1048562        NEW DELHI
# 1048563           NASHIK
# 1048564        HYDERABAD
# 1048565    VISAKHAPATNAM
# 1048566             PUNE
# Name: CustLocation, Length: 984614, dtype: object

# %%
transaction_count_by_city = data.groupby('CustLocation')['TransactionID'].count().reset_index()
new_column_names = {'CustLocation': 'Location', 'TransactionID': 'TransactionCount'}
transaction_count_by_city.rename(columns = new_column_names, inplace=True)

# %%
transaction_count_by_city.head()
# Out:
#                    Location  TransactionCount
# 0  (154) BHASKOLA FARIDABAD                11
# 1   (BENAKA MDTS) BANGALORE                21
# 2                (DT) HOSUR                11
# 3                (E) MUMBAI                44
# 4        (E) THANE SECTOR 3                 1

# %%
transaction_count_by_city['TransactionCount'].mean()
# Out:
# 120.64869501286607

# %% [markdown]
# We have over 8,000 cities, and the average number of transactions per city is approximately 121. Let's take a closer look at the top 10 most frequent cities.

# %%
top_10 = transaction_count_by_city.nlargest(10, 'TransactionCount')
not_top_10 = transaction_count_by_city.nsmallest(transaction_count_by_city.shape[0] - 10, 'TransactionCount')

# %%
not_top_10['TransactionCount'].sum()
# Out:
# 468893

# %%
new_entry = pd.DataFrame({'Location': ['OTHER'], 'TransactionCount': [468893]})
top_10_others = pd.concat([top_10, new_entry])

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#aec7e8']
plt.pie(top_10_others['TransactionCount'], labels=None, startangle=90, colors=colors)
plt.legend(top_10_others['Location'], loc='best', bbox_to_anchor=(1, 0.5), fontsize='small') # urednije je preko legende
plt.show(block=False) # ne prikazuje blok teksta

# %% [markdown]
# So, the top 10 most frequent cities collectively account for more than 50 percent of the transactions. The bank should pay special attention to these cities as they constitute the majority of users.

# %% [markdown]
# # **10. Can we deduce the bank's activity in cities solely from this number? If not, what is the alternative?**

# %% [markdown]
# Considering that cities differ in population, a better measure of activity per city would be the relative measure of transactions per population. Let's extract this measure for the top 10 most active cities and see where the bank has relatively the most users.

# %%
top_10['Location']
# Out:
# 4623       MUMBAI
# 672     BANGALORE
# 5064    NEW DELHI
# 2688      GURGAON
# 1805        DELHI
# 5149        NOIDA
# 1409      CHENNAI
# 5840         PUNE
# 2953    HYDERABAD
# 7297        THANE
# Name: Location, dtype: object

# %% [markdown]
# A potential issue with this metric is that these locations are not all entirely distinct cities. For example, New Delhi and Delhi, when considering the metropolitan region, are the same. Therefore, for their calculation, we will use the sum of transactions. We will do the same for Mumbai and Thane.

# %%
city_pop = {'City': ['MUMBAI', 'Bangalore', 'New Delhi', 'Gurgaon', 'Delhi', 'Noida', 'Chennai', 'Pune', 'Hyderabad', 'Thane'],
        'Value': [21.3, 13.6, 32.9, 1.2, 32.9, 0.6, 8.7, 5.0, 10.8, 21.3]}

city_pop = pd.DataFrame(city_pop)
top_10['Population'] = [21.3, 13.6, 32.9, 1.2, 32.9, 0.6, 8.7, 5.0, 10.8, 21.3]

# %%
top_10
# Out:
#        Location  TransactionCount  Population
# 4623     MUMBAI             97605        21.3
# 672   BANGALORE             77688        13.6
# 5064  NEW DELHI             76307        32.9
# 2688    GURGAON             70447         1.2
# 1805      DELHI             67263        32.9
# 5149      NOIDA             31650         0.6
# 1409    CHENNAI             27488         8.7
# 5840       PUNE             24483         5.0
# 2953  HYDERABAD             21793        10.8
# 7297      THANE             20997        21.3

# %%
top_10.loc[top_10['Location'] == 'MUMBAI', 'TransactionCount'] = 97605 + 20997
top_10.loc[top_10['Location'] == 'DELHI', 'TransactionCount'] = 76307 + 67263
values_to_drop = ['NEW DELHI', 'THANE']
top_8 = top_10[~top_10['Location'].isin(values_to_drop)]

# %%
top_8
# Out:
#        Location  TransactionCount  Population
# 4623     MUMBAI            118602        21.3
# 672   BANGALORE             77688        13.6
# 2688    GURGAON             70447         1.2
# 1805      DELHI            143570        32.9
# 5149      NOIDA             31650         0.6
# 1409    CHENNAI             27488         8.7
# 5840       PUNE             24483         5.0
# 2953  HYDERABAD             21793        10.8

# %%
top_8['Activity'] = top_8['TransactionCount']/top_8['Population']
top_8['Activity'] = top_8['Activity']/top_8['Activity'].max()
# Out:
# <ipython-input-346-f3db90bccdb1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_8['Activity'] = top_8['TransactionCount']/top_8['Population']
# <ipython-input-346-f3db90bccdb1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_8['Activity'] = top_8['Activity']/top_8['Activity'].max()

# %%
top_8.sort_values(by='Activity', ascending=False)
# Out:
#        Location  TransactionCount  Population  Activity
# 2688    GURGAON             70447         1.2  1.000000
# 5149      NOIDA             31650         0.6  0.898548
# 672   BANGALORE             77688        13.6  0.097305
# 4623     MUMBAI            118602        21.3  0.094849
# 5840       PUNE             24483         5.0  0.083409
# 1805      DELHI            143570        32.9  0.074334
# 1409    CHENNAI             27488         8.7  0.053820
# 2953  HYDERABAD             21793        10.8  0.034373

# %% [markdown]
# We observe that, proportionally to the population, Gurgaon is the city where the bank is most represented. Of course, this doesn't necessarily mean the bank should focus its activities there, first because it is already evidently popular, and second because in terms of the absolute number of transactions, Mumbai and Delhi are much more crucial centers.
